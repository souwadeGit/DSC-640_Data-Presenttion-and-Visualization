# %% [markdown]
# ### Exercise 2.2
#
# You need to submit 3 tree maps, 3 area charts, 3 stacked area charts, and 3 step charts using Tableau or PowerBI, Python and R using the data below (or your own datasets). You can also submit using D3. You can choose which library to use in Python or R, documentation is provided to help you decide and as you start to play around in the libraries, you will decide which you prefer.

# %% [markdown]
# ### Load Librares

# %%
#pip install squarify

# %%
import pandas as pd                        #This is used to create data frames and also read and write files
import numpy as np                         #importing the numpy library for scientific calculation
import matplotlib.pyplot as plt            #This is also used for plotting         
import matplotlib as mpl
import warnings
import squarify
from datetime import datetime as dt

# Use to configure display of graph
# %matplotlib inline 

#stop unnecessary warnings from printing to the screen
warnings.simplefilter('ignore')

# %% [markdown]
# ### Import Datasets

# %%
# read an csv file and store in a variable Unemplyement_rate
Unemplyement_rate = pd.read_csv("unemployement-rate-1948-2010.csv")

#Loads the csv file into a pandas data frame
df1 = pd.read_csv("unemployement-rate-1948-2010.csv")

#read the fisrt five variable
print(df1.head())
# Out:
#      Series id  Year Period  Value
# 0  LNS14000000  1948    M01    3.4
# 1  LNS14000000  1948    M02    3.8
# 2  LNS14000000  1948    M03    4.0
# 3  LNS14000000  1948    M04    3.9
# 4  LNS14000000  1948    M05    3.5

# %%
#us-postage# read and Load the exel file into a pandas data frame
df2 = pd.read_excel("us-postage.xlsm")

# the first five rows
df2.head()
# Out:
#    Year  Price
# 0  1991   0.29
# 1  1995   0.32
# 2  1999   0.33
# 3  2001   0.34
# 4  2002   0.37

# %%
# read from local directory and Load the exel file into a pandas data frame
df3 = pd.read_excel("world-population.xlsm")

# the first five rows
df3.head()
# Out:
#    Year  Population
# 0  1960  3028654024
# 1  1961  3068356747
# 2  1962  3121963107
# 3  1963  3187471383
# 4  1964  3253112403

# %% [markdown]
# ### Tree map chart
#
# Treemapping is a data visualization technique that is used to display hierarchical data using nested rectangles; the treemap chart is created based on this technique of data visualization. The treemap chart is used for representing hierarchical data in a tree-like structure. It provides a hierarchical view of your data and makes it easy to spot patterns, such as which items are a store's best sellers. The tree branches are represented by rectangles and each sub-branch is shown as a smaller rectangle. A sunburst chart is a much better visual chart for showing that.
#
# Basic Treemap with python relies on the squarify library. This treemap only has one group level. The input is just a set of numeric value. Each square will be as big as its value.
#
# https://python-graph-gallery.com/treemap/

# %%
#libraries
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import squarify # pip install squarify (algorithm for treemap)&lt;/pre&gt;

#Here is a tip to map a color on the values of each group of a treemap with colors mapped on values

# Create a dataset:
my_values=[i**3 for i in range(1,100)]
 
# create a color palette, mapped to these values
cmap = matplotlib.cm.Blues
mini=min(my_values)
maxi=max(my_values)
norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in my_values]
 
# Change color
squarify.plot(sizes=my_values, alpha=.8, color=colors )
plt.axis('off')
plt.show()

# %% [markdown]
# ### Control the color of Treemap
#
# This page aims to describe the customization you can apply on a treemap. You can easily change the color of each group using the following code:

# %%
#libraries
import matplotlib.pyplot as plt
import squarify # pip install squarify (algorithm for treemap)

#describe the customization you can apply on a treemap-change the color of each group
# Change color
squarify.plot(sizes=[13,22,35,5], label=["school A", "school B", "school C", "school D"], color=["blue","yellow","red", "grey"], alpha=.4 )
plt.axis('off')
plt.show()

# %% [markdown]
# ### 3 Area Charts
#
# An area chart is really similar to a line chart and represents the evolution of a numeric variable. Basically, the X axis represents time or an ordered variable, and the Y axis gives the value of another variable. Data points are connected by straight line segments and the area between the x axis and the line is filled in with color or shading.

# %%
df1.plot.area()

# %%
df1.columns
# Out:
# Index(['Series id', 'Year', 'Period', 'Value'], dtype='object')

# %%
# plot
df2.plot.area()

# %%
df2.columns
# Out:
# Index(['Year', 'Price'], dtype='object')

# %%
# plot
df3.plot.area()

# %%
df3.columns
# Out:
# Index(['Year', 'Population'], dtype='object')

# %% [markdown]
# ### 3 Stacked area chart
# A stacked area chart is the extension of a basic area chart to display the evolution of the value of several groups on the same graphic. The values of each group are displayed on top of each other. It allows to check on the same figure the evolution of both the total of a numeric variable, and the importance of each group. If only the relative importance of each group interests you, you should probably draw a percent stacked area chart.
#
# Note that this chart becomes hard to read if too many groups are displayed and if the patterns are really different between groups. In this case, think about using faceting instead.

# %%
# library
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
 
# Make data
data = pd.DataFrame({  'group_A':[1,4,6,8,9], 'group_B':[2,24,7,10,12], 'group_C':[2,8,5,10,6], }, index=range(1,6))
 
# We need to transform the data from raw data to percentage (fraction)
data_perc = data.divide(data.sum(axis=1), axis=0)
 
# Make the plot
plt.stackplot(range(1,6),  data_perc["group_A"],  data_perc["group_B"],  data_perc["group_C"], labels=['A','B','C'])
plt.legend(loc='upper left')
plt.margins(0,0)
plt.title('100 % stacked area chart')
plt.show()

# %% [markdown]
# ### Baseline options for stacked area chart
#
# The stackplot function of Matplotlib allows to make stacked area chart. It provides a baseline argument that allow to custom the position of the areas around the baseline. Four possibilities exist, and are represented here.

# %%
# library
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
# Create data
X = np.arange(0, 10, 1)
Y = X + 5 * np.random.random((5, X.size))
 
# There are 4 types of baseline we can use:
baseline = ["zero", "sym", "wiggle", "weighted_wiggle"]
 
# Let's make 4 plots, 1 for each baseline
for n, v in enumerate(baseline):
   if n<3 :
      plt.tick_params(labelbottom='off')
   plt.subplot(2 ,2, n + 1)
   plt.stackplot(X, *Y, baseline=v)
   plt.title(v)
   plt.axis('tight', size=0.2)

# %% [markdown]
# ### pylab_examples example code: stackplot_demo.py
#
# https://matplotlib.org/examples/pylab_examples/stackplot_demo.html

# %%
import numpy as np
import matplotlib.pyplot as plt


def fnx():
    return np.random.randint(5, 50, 10)

y = np.row_stack((fnx(), fnx(), fnx()))
x = np.arange(10)

y1, y2, y3 = fnx(), fnx(), fnx()

fig, ax = plt.subplots()
ax.stackplot(x, y)
plt.show()

fig, ax = plt.subplots()
ax.stackplot(x, y1, y2, y3)
plt.show()

# %% [markdown]
# ### 3 Step Charts
#
# step chart can be useful when you want to show the changes that occur at irregular intervals. For example, price rise in milk products, petrol, tax rate, interest rates, etc.
#
# ### Line Chart Vs. Step Chart
#
# A line chart would connect the data points in such a way that you see a trend. The focus in such charts is the trend and not the exact time of change.
#
# On the contrary, a step chart shows the exact time of change in the data along with the trend. You can easily spot the time period where there was no change and can compare the magnitude of change at each instance.

# %%
import pandas as pd  
# read from local directory and Load the exel file into a pandas data frame
df3 = pd.read_excel("world-population.xlsm")
# the first five rows
#df3.head()

# %%
# The datset world-population is stored in df3
X = df3['Year']
Y = df3['Population']

# %% [markdown]
# ### Line Chart

# %%
#Line Chart
plt.plot(X, Y)
plt.show()

# %% [markdown]
# ### 3 step chart

# %%
plt.step(X, Y)
plt.show()

# %%
df2 = pd.read_excel("us-postage.xlsm")

# %%
# Line graph
X = df2['Year']
Y = df2['Price']
plt.plot(X, Y)
plt.show()

# %%
df1 = pd.read_csv("unemployement-rate-1948-2010.csv")
#df1
#Line graph
X = df1['Year']
Y = df1['Value']
#plt.plot(X, Y)
#plt.show()
# Step graph
plt.step(X, Y)
plt.show()
